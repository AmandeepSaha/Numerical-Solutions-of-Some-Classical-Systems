# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0.1,2*np.pi,10000)
y = x*np.exp(1j*x)

# %%
for i in range(10):
    y = x**2*np.exp(1j*x*i)
    plt.plot(y.real,y.imag)
    plt.pause(.1)

# %%
plt.plot(y.real,y.imag)

# %%
y.real,y.imag
# Out:
# (array([6.21609968e-03, 6.24898213e-03, 6.28105330e-03, ...,
#         3.94604329e+01, 3.94700359e+01, 3.94784176e+01]),
#  array([ 7.83326910e-03,  7.96534884e-03,  8.09863853e-03, ...,
#         -4.39246168e-01, -2.19669726e-01, -8.70248120e-14]))
