# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
pd.set_option('display.max_column',200)

# %%
df = pd.read_csv(r"D:\dataset\DA\dielectron.csv")

# %%
df.head(20)
# Out:
#        Run      Event        E1       px1         py1       pz1       pt1  \
# 0   147115  366639895  58.71410  -7.311320  10.531000 -57.29740  12.82020
# 1   147115  366704169   6.61188  -4.152130  -0.579855  -5.11278   4.19242
# 2   147115  367112316  25.54190 -11.480900   2.041680  22.72460  11.66100
# 3   147115  366952149  65.39590   7.512140  11.887100  63.86620  14.06190
# 4   147115  366523212  61.45040   2.952840 -14.622700 -59.61210  14.91790
# 5   147115  366663412   6.39616  -5.456720  -2.090680  -2.60078   5.84352
# 6   147115  366639101  84.50580   8.824360  10.578900  83.37530  13.77610
# 7   147115  367133576  77.00570  10.002900   9.175450 -75.80000  13.57370
# 8   147115  368639137   9.68787   1.111920   2.050640  -9.40284   2.33270
# 9   147115  367825395  27.88120  11.939000 -18.346200  17.26960  21.88880
# 10  147115  368386363   3.55057   1.828420   1.441290  -2.68069   2.32818
# 11  147115  367872476   2.91574   2.297280  -1.262960   1.27631   2.62156
# ...

# %%
df['Run'].unique()
# Out:
# array([147115, 146644, 149181, 147114, 149011, 148031, 147754, 147929,
#        148029, 147926, 146944, 149182, 146511])

# %%
df.shape
# Out:
# (100000, 19)

# %%
[i for i in df['M'].isna()].index(True)
# Out:
# 2354

# %%
df.loc[2354,'M']
# Out:
# np.float64(nan)

# %%
df['M']=df['M'].replace(df.loc[2354,'M'],df['M'].median())

# %%
df.isna().sum()
# Out:
# Run      0
# Event    0
# E1       0
# px1      0
# py1      0
# pz1      0
# pt1      0
# eta1     0
# phi1     0
# Q1       0
# E2       0
# px2      0
# py2      0
# pz2      0
# pt2      0
# eta2     0
# phi2     0
# Q2       0
# M        0
# dtype: int64

# %%
plt.hist(df['M'].dropna(), bins=100)
plt.xlabel('Invariant Mass [GeV]')
plt.ylabel('Number of Events')
# Out:
# Text(0, 0.5, 'Number of Events')

# %%
df.groupby('Run')['M'].mean().head(200).plot(kind='bar')
plt.ylabel('Invarient Mass')
# Out:
# Text(0, 0.5, 'Invarient Mass')
